# %%
import advertools as adv
import adviz
import pandas as pd
pd.options.display.max_columns = None
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# ## Read the csv file exported from BigQuery

# %%
gsc = pd.read_csv('gsc_big_query_export_url.csv')

# %% [markdown]
# ## Remove all `is_<search_appearance_type>` columns that contain all `False` values

# %%
drop_bools = gsc.select_dtypes(bool).columns[gsc.select_dtypes(bool).sum().eq(0)]
gsc = gsc.drop(drop_bools, axis=1)

# %% [markdown]
# ## Convert `data_date` to datetime type

# %%
gsc['data_date'] = pd.to_datetime(gsc['data_date'], format='%d/%m/%Y')

# %% [markdown]
# ## Add country flags

# %%
gsc['flag'] = [adviz.flag(x) for x in gsc['country']]

# %% [markdown]
# ## Split URLs and combine relevant columns with original DataFrame

# %%
urldf = adv.url_to_df(gsc['url'])
gsc = pd.concat([gsc, urldf.filter(regex=r'^dir_\d')], axis=1)
gsc['dir_1'] = gsc['dir_1'].fillna('/')

# %%
gsc.head()
# Out:
#    data_date               site_url  \
# 0 2024-07-05  https://nbastats.pro/
# 1 2024-07-05  https://nbastats.pro/
# 2 2024-07-05  https://nbastats.pro/
# 3 2024-07-05  https://nbastats.pro/
# 4 2024-07-05  https://nbastats.pro/
#
#                                           url query  is_anonymized_query  \
# 0                       https://nbastats.pro/   NaN                 True
# 1      https://nbastats.pro/player/Larry_Bird   NaN                 True
# 2     https://nbastats.pro/player/Robin_Jones   NaN                 True
# 3        https://nbastats.pro/player/Rick_Fox   NaN                 True
# 4  https://nbastats.pro/player/Tony_Robertson   NaN                 True
#
#   country search_type   device  impressions  clicks  sum_position flag  \
# 0     are         WEB   MOBILE            1       0             0   🇦🇪
# 1     usa         WEB  DESKTOP            1       0            13   🇺🇸
# 2     are         WEB   MOBILE            1       0             5   🇦🇪
# 3     are         WEB   MOBILE            1       0            10   🇦🇪
# 4     are         WEB   MOBILE            1       0             8   🇦🇪
#
#     dir_1           dir_2
# 0       /            None
# 1  player      Larry_Bird
# 2  player     Robin_Jones
# 3  player        Rick_Fox
# 4  player  Tony_Robertson

# %% [markdown]
# ## Create query categories and regexes to match them

# %%
query_cat = {
    'basketball': r'basketbal',
    'stats': r'statistics|stats',
    'career': r'career',
}

# %% [markdown]
# ## Create `cat_` columns for each of the created categories

# %%
for cat, regex in query_cat.items():
    gsc[f'cat_{cat}'] = gsc['query'].fillna('').str.contains(regex, regex=True)

# %%
gsc.dropna(subset=['query']).drop(['site_url', 'is_anonymized_query'], axis=1).sample(15).style.background_gradient(subset=gsc.filter(regex='cat_').columns.tolist() + ['impressions', 'clicks', 'sum_position'], cmap='cividis')
# Out:
# <style type="text/css">
# #T_de385_row0_col6, #T_de385_row0_col7, #T_de385_row0_col12, #T_de385_row0_col14, #T_de385_row1_col6, #T_de385_row1_col7, #T_de385_row1_col12, #T_de385_row1_col14, #T_de385_row2_col6, #T_de385_row2_col7, #T_de385_row2_col8, #T_de385_row2_col12, #T_de385_row3_col6, #T_de385_row3_col7, #T_de385_row3_col12, #T_de385_row3_col14, #T_de385_row4_col6, #T_de385_row4_col7, #T_de385_row4_col12, #T_de385_row4_col14, #T_de385_row5_col6, #T_de385_row5_col7, #T_de385_row5_col8, #T_de385_row5_col12, #T_de385_row5_col14, #T_de385_row6_col6, #T_de385_row6_col7, #T_de385_row6_col12, #T_de385_row6_col14, #T_de385_row7_col7, #T_de385_row7_col12, #T_de385_row7_col14, #T_de385_row8_col6, #T_de385_row8_col7, #T_de385_row8_col12, #T_de385_row9_col6, #T_de385_row9_col12, #T_de385_row9_col14, #T_de385_row10_col6, #T_de385_row10_col7, #T_de385_row10_col12, #T_de385_row10_col14, #T_de385_row11_col6, #T_de385_row11_col7, #T_de385_row11_col12, #T_de385_row11_col13, #T_de385_row11_col14, #T_de385_row12_col6, #T_de385_row12_col7, #T_de385_row12_col12, #T_de385_row12_col14, #T_de385_row13_col6, #T_de385_row13_col7, #T_de385_row13_col12, #T_de385_row13_col13, #T_de385_row13_col14, #T_de385_row14_col6, #T_de385_row14_col7, #T_de385_row14_col12, #T_de385_row14_col14 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_de385_row0_col8 {
#   background-color: #053371;
#   color: #f1f1f1;
# }
# #T_de385_row0_col13, #T_de385_row1_col13, #T_de385_row2_col13, #T_de385_row2_col14, #T_de385_row3_col13, #T_de385_row4_col13, #T_de385_row5_col13, #T_de385_row6_col13, #T_de385_row7_col6, #T_de385_row7_col8, #T_de385_row7_col13, #T_de385_row8_col13, #T_de385_row8_col14, #T_de385_row9_col7, #T_de385_row9_col13, #T_de385_row10_col13, #T_de385_row12_col13, #T_de385_row14_col13 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_de385_row1_col8 {
#   background-color: #0c3470;
#   color: #f1f1f1;
# }
# #T_de385_row3_col8 {
#   background-color: #002b62;
#   color: #f1f1f1;
# }
# #T_de385_row4_col8 {
#   background-color: #003171;
#   color: #f1f1f1;
# }
# #T_de385_row6_col8 {
#   background-color: #3a486c;
#   color: #f1f1f1;
# }
# #T_de385_row8_col8 {
#   background-color: #002f6d;
#   color: #f1f1f1;
# }
# #T_de385_row9_col8 {
#   background-color: #002e6a;
#   color: #f1f1f1;
# }
# #T_de385_row10_col8 {
#   background-color: #203a6f;
#   color: #f1f1f1;
# }
# #T_de385_row11_col8 {
#   background-color: #555b6d;
#   color: #f1f1f1;
# }
# #T_de385_row12_col8 {
#   background-color: #002554;
#   color: #f1f1f1;
# }
# #T_de385_row13_col8 {
#   background-color: #434e6c;
#   color: #f1f1f1;
# }
# #T_de385_row14_col8 {
#   background-color: #263d6e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_de385">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de385_level0_col0" class="col_heading level0 col0" >data_date</th>
#       <th id="T_de385_level0_col1" class="col_heading level0 col1" >url</th>
#       <th id="T_de385_level0_col2" class="col_heading level0 col2" >query</th>
#       <th id="T_de385_level0_col3" class="col_heading level0 col3" >country</th>
#       <th id="T_de385_level0_col4" class="col_heading level0 col4" >search_type</th>
#       <th id="T_de385_level0_col5" class="col_heading level0 col5" >device</th>
#       <th id="T_de385_level0_col6" class="col_heading level0 col6" >impressions</th>
#       <th id="T_de385_level0_col7" class="col_heading level0 col7" >clicks</th>
#       <th id="T_de385_level0_col8" class="col_heading level0 col8" >sum_position</th>
#       <th id="T_de385_level0_col9" class="col_heading level0 col9" >flag</th>
#       <th id="T_de385_level0_col10" class="col_heading level0 col10" >dir_1</th>
#       <th id="T_de385_level0_col11" class="col_heading level0 col11" >dir_2</th>
#       <th id="T_de385_level0_col12" class="col_heading level0 col12" >cat_basketball</th>
#       <th id="T_de385_level0_col13" class="col_heading level0 col13" >cat_stats</th>
#       <th id="T_de385_level0_col14" class="col_heading level0 col14" >cat_career</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de385_level0_row0" class="row_heading level0 row0" >220</th>
#       <td id="T_de385_row0_col0" class="data row0 col0" >2024-09-05 00:00:00</td>
#       <td id="T_de385_row0_col1" class="data row0 col1" >https://nbastats.pro/player/Luol_Deng</td>
#       <td id="T_de385_row0_col2" class="data row0 col2" >luol deng stats</td>
#       <td id="T_de385_row0_col3" class="data row0 col3" >fin</td>
#       <td id="T_de385_row0_col4" class="data row0 col4" >WEB</td>
#       <td id="T_de385_row0_col5" class="data row0 col5" >DESKTOP</td>
#       <td id="T_de385_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_de385_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_de385_row0_col8" class="data row0 col8" >23</td>
#       <td id="T_de385_row0_col9" class="data row0 col9" >🇫🇮</td>
#       <td id="T_de385_row0_col10" class="data row0 col10" >player</td>
#       <td id="T_de385_row0_col11" class="data row0 col11" >Luol_Deng</td>
#       <td id="T_de385_row0_col12" class="data row0 col12" >False</td>
#       <td id="T_de385_row0_col13" class="data row0 col13" >True</td>
#       <td id="T_de385_row0_col14" class="data row0 col14" >False</td>
#     </tr>
#     <tr>
#       <th id="T_de385_level0_row1" class="row_heading level0 row1" >52</th>
#       <td id="T_de385_row1_col0" class="data row1 col0" >2024-07-05 00:00:00</td>
#       <td id="T_de385_row1_col1" class="data row1 col1" >https://nbastats.pro/player/Chuck_Cooper</td>
#       <td id="T_de385_row1_col2" class="data row1 col2" >chuck cooper stats</td>
#       <td id="T_de385_row1_col3" class="data row1 col3" >gbr</td>
#       <td id="T_de385_row1_col4" class="data row1 col4" >WEB</td>
#       <td id="T_de385_row1_col5" class="data row1 col5" >DESKTOP</td>
#       <td id="T_de385_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_de385_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_de385_row1_col8" class="data row1 col8" >24</td>
#       <td id="T_de385_row1_col9" class="data row1 col9" >🇬🇧</td>
#       <td id="T_de385_row1_col10" class="data row1 col10" >player</td>
#       <td id="T_de385_row1_col11" class="data row1 col11" >Chuck_Cooper</td>
#       <td id="T_de385_row1_col12" class="data row1 col12" >False</td>
#       <td id="T_de385_row1_col13" class="data row1 col13" >True</td>
#       <td id="T_de385_row1_col14" class="data row1 col14" >False</td>
#     </tr>
#     <tr>
#       <th id="T_de385_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_de385_row2_col0" class="data row2 col0" >2024-07-05 00:00:00</td>
#       <td id="T_de385_row2_col1" class="data row2 col1" >https://nbastats.pro/player/Larry_Bird</td>
#       <td id="T_de385_row2_col2" class="data row2 col2" >bird career stats</td>
#       <td id="T_de385_row2_col3" class="data row2 col3" >bhs</td>
#       <td id="T_de385_row2_col4" class="data row2 col4" >WEB</td>
#       <td id="T_de385_row2_col5" class="data row2 col5" >MOBILE</td>
#       <td id="T_de385_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_de385_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_de385_row2_col8" class="data row2 col8" >11</td>
#       <td id="T_de385_row2_col9" class="data row2 col9" >🇧🇸</td>
#       <td id="T_de385_row2_col10" class="data row2 col10" >player</td>
#       <td id="T_de385_row2_col11" class="data row2 col11" >Larry_Bird</td>
#       <td id="T_de385_row2_col12" class="data row2 col12" >False</td>
#       <td id="T_de385_row2_col13" class="data row2 col13" >True</td>
#       <td id="T_de385_row2_col14" class="data row2 col14" >True</td>
#     </tr>
#     <tr>
#       <th id="T_de385_level0_row3" class="row_heading level0 row3" >274</th>
#       <td id="T_de385_row3_col0" class="data row3 col0" >2024-09-05 00:00:00</td>
#       <td id="T_de385_row3_col1" class="data row3 col1" >https://nbastats.pro/player/Larry_Bird</td>
#       <td id="T_de385_row3_col2" class="data row3 col2" >larry bord stats</td>
#       <td id="T_de385_row3_col3" class="data row3 col3" >usa</td>
#       <td id="T_de385_row3_col4" class="data row3 col4" >WEB</td>
#       <td id="T_de385_row3_col5" class="d
